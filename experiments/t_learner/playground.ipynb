# %%
import sys
from pathlib import Path

REPO = Path("/home/felixhu/WeatherEngression")
if str(REPO) not in sys.path:
    sys.path.insert(0, str(REPO))

# %%
import pickle
import numpy as np
import pandas as pd
from data_generation.ena_weather import ENADataset

# %%
# Load dataset
with open("/storage3/fs1/myu/Active/felixhu/weather_checkpoints/runs/real_data_diagnostics/ena_weather/log10_ccn/paper/t_learner/BB_criterion1_recurrent_2200505/dataset/dataset_obj.pkl", "rb") as f:
    dataset: ENADataset = pickle.load(f)
with open("/storage3/fs1/myu/Active/felixhu/weather_checkpoints/runs/real_data_diagnostics/ena_weather/log10_ccn/paper/t_learner/BB_criterion1_recurrent_2200505/dataset/test_no_wildfire_idx.pkl", "rb") as f:
    test_no_wildfire_idx = pickle.load(f)
with open("/storage3/fs1/myu/Active/felixhu/weather_checkpoints/runs/real_data_diagnostics/ena_weather/log10_ccn/paper/t_learner/BB_criterion1_recurrent_2200505/dataset/test_wildfire_idx.pkl", "rb") as f:
    test_wildfire_idx = pickle.load(f)
with open("/storage3/fs1/myu/Active/felixhu/weather_checkpoints/runs/real_data_diagnostics/ena_weather/log10_ccn/paper/t_learner/BB_criterion1_recurrent_2200505/dataset/train_no_wildfire_idx.pkl", "rb") as f:
    train_no_wildfire_idx = pickle.load(f)
with open("/storage3/fs1/myu/Active/felixhu/weather_checkpoints/runs/real_data_diagnostics/ena_weather/log10_ccn/paper/t_learner/BB_criterion1_recurrent_2200505/dataset/train_wildfire_idx.pkl", "rb") as f:
    train_wildfire_idx = pickle.load(f)

# %%
# Let's see how many test datapoints are weather vs not
print("total test datapoints", dataset.x.shape)
print(train_no_wildfire_idx.shape, train_wildfire_idx.shape)
print(test_no_wildfire_idx.shape, test_wildfire_idx.shape)
print(train_no_wildfire_idx.shape[0] + train_wildfire_idx.shape[0] + test_no_wildfire_idx.shape[0] + test_wildfire_idx.shape[0])
# Out:
# total test datapoints (60866, 241, 22)
# (51214,) (6378,)
# (2812,) (408,)
# 60812
